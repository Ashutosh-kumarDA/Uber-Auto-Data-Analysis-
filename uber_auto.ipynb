# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('c:/datasets/ncr_ride_bookings.csv')
df
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df.drop(['Reason for cancelling by Customer','Cancelled Rides by Driver','Driver Cancellation Reason','Incomplete Rides','Incomplete Rides Reason'],axis=1,inplace=True)

# %%
df.drop(['Cancelled Rides by Customer'],axis=1,inplace=True)

# %%
df
# Out:
#               Date      Time    Booking ID   Booking Status   Customer ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# ...

# %%
df.rename({'Payment Method':'Payment_Method'},axis=1,inplace=True)

# %%
df.rename({'Booking ID':'Booking_ID','Booking Status':'Booking_Status','Customer ID':'Customer_ID','Vehicle Type':'Vehicle_Type','Pickup Location':'Pickup_Location','Drop Location':'Drop_Location'},axis=1,inplace=True)
df
# Out:
#               Date      Time    Booking_ID   Booking_Status   Customer_ID  \
# 0       2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1       2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2       2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...            ...       ...           ...              ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle_Type         Pickup_Location      Drop_Location  Avg VTAT  \
# ...

# %%
df[(df.Booking_Status=='Completed') & (df.Payment_Method.isnull())].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df[(df.Booking_Status=='Incomplete') & (df.Payment_Method.isnull())].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df[(df.Booking_Status=='No Driver Found') & (df.Payment_Method.isnull())].sum()
# Out:
# Date               2024-03-232024-09-142024-09-182024-04-122024-0...
# Time               12:29:3812:49:0908:09:3819:42:3515:43:3418:58:...
# Booking_ID         "CNR5884300""CNR4510807""CNR9551927""CNR449938...
# Booking_Status     No Driver FoundNo Driver FoundNo Driver FoundN...
# Customer_ID        "CID1982111""CID7873618""CID7568143""CID571752...
# Vehicle_Type       eBikeGo SedanAutoPremier SedanUber XLGo MiniUb...
# Pickup_Location    Palam ViharNoida Sector 62Vidhan SabhaSadar Ba...
# Drop_Location      JhilmilNoida Sector 18AIIMSMehrauliDwarka Sect...
# Avg VTAT                                                         0.0
# Avg CTAT                                                         0.0
# Booking Value                                                    0.0
# Ride Distance                                                    0.0
# Driver Ratings                                                   0.0
# Customer Rating                                                  0.0
# ...

# %%
df.dropna(axis=0,inplace=True)
df
# Out:
#               Date      Time    Booking_ID Booking_Status   Customer_ID  \
# 2       2024-08-23  08:56:10  "CNR8494506"      Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"      Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"      Completed  "CID9933542"
# 5       2024-02-06  09:44:56  "CNR4096693"      Completed  "CID4670564"
# 6       2024-06-17  15:45:58  "CNR2002539"      Completed  "CID6800553"
# ...            ...       ...           ...            ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"      Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"      Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"      Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"      Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"      Completed  "CID4108667"
#
#          Vehicle_Type         Pickup_Location      Drop_Location  Avg VTAT  \
# ...

# %%
df.Payment_Method.unique()
# Out:
# array(['Debit Card', 'UPI', 'Cash', 'Uber Wallet', 'Credit Card'],
#       dtype=object)

# %%
df.Booking_Status.unique()
# Out:
# array(['Completed'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93000 entries, 2 to 149999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             93000 non-null  object
#  1   Time             93000 non-null  object
#  2   Booking_ID       93000 non-null  object
#  3   Booking_Status   93000 non-null  object
#  4   Customer_ID      93000 non-null  object
#  5   Vehicle_Type     93000 non-null  object
#  6   Pickup_Location  93000 non-null  object
#  7   Drop_Location    93000 non-null  object
#  8   Avg VTAT         93000 non-null  float64
#  9   Avg CTAT         93000 non-null  float64
#  10  Booking Value    93000 non-null  float64
#  11  Ride Distance    93000 non-null  float64
#  12  Driver Ratings   93000 non-null  float64
#  13  Customer Rating  93000 non-null  float64
#  14  Payment_Method   93000 non-null  object
# dtypes: float64(6), object(9)
# memory usage: 11.4+ MB

# %%
df['New_Date']=pd.to_datetime(df.Date,format="%Y-%m-%d")
df
# Out:
#               Date      Time    Booking_ID Booking_Status   Customer_ID  \
# 2       2024-08-23  08:56:10  "CNR8494506"      Completed  "CID9202816"
# 3       2024-10-21  17:17:25  "CNR8906825"      Completed  "CID2610914"
# 4       2024-09-16  22:08:00  "CNR1950162"      Completed  "CID9933542"
# 5       2024-02-06  09:44:56  "CNR4096693"      Completed  "CID4670564"
# 6       2024-06-17  15:45:58  "CNR2002539"      Completed  "CID6800553"
# ...            ...       ...           ...            ...           ...
# 149995  2024-11-11  19:34:01  "CNR6500631"      Completed  "CID4337371"
# 149996  2024-11-24  15:55:09  "CNR2468611"      Completed  "CID2325623"
# 149997  2024-09-18  10:55:15  "CNR6358306"      Completed  "CID9925486"
# 149998  2024-10-05  07:53:34  "CNR3030099"      Completed  "CID9415487"
# 149999  2024-03-10  15:38:03  "CNR3447390"      Completed  "CID4108667"
#
#          Vehicle_Type         Pickup_Location      Drop_Location  Avg VTAT  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93000 entries, 2 to 149999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             93000 non-null  object
#  1   Time             93000 non-null  object
#  2   Booking_ID       93000 non-null  object
#  3   Booking_Status   93000 non-null  object
#  4   Customer_ID      93000 non-null  object
#  5   Vehicle_Type     93000 non-null  object
#  6   Pickup_Location  93000 non-null  object
#  7   Drop_Location    93000 non-null  object
#  8   Avg VTAT         93000 non-null  float64
#  9   Avg CTAT         93000 non-null  float64
#  10  Booking Value    93000 non-null  float64
#  11  Ride Distance    93000 non-null  float64
#  12  Driver Ratings   93000 non-null  float64
#  13  Customer Rating  93000 non-null  float64
#  14  Payment_Method   93000 non-null  object
#  15  New_Date         93000 non-null  datetime64[ns]
# ...

# %%
df.drop('Date',inplace=True,axis=1)

# %%
df
# Out:
#             Time    Booking_ID Booking_Status   Customer_ID   Vehicle_Type  \
# 2       08:56:10  "CNR8494506"      Completed  "CID9202816"           Auto
# 3       17:17:25  "CNR8906825"      Completed  "CID2610914"  Premier Sedan
# 4       22:08:00  "CNR1950162"      Completed  "CID9933542"           Bike
# 5       09:44:56  "CNR4096693"      Completed  "CID4670564"           Auto
# 6       15:45:58  "CNR2002539"      Completed  "CID6800553"        Go Mini
# ...          ...           ...            ...           ...            ...
# 149995  19:34:01  "CNR6500631"      Completed  "CID4337371"        Go Mini
# 149996  15:55:09  "CNR2468611"      Completed  "CID2325623"        Go Mini
# 149997  10:55:15  "CNR6358306"      Completed  "CID9925486"       Go Sedan
# 149998  07:53:34  "CNR3030099"      Completed  "CID9415487"           Auto
# 149999  15:38:03  "CNR3447390"      Completed  "CID4108667"  Premier Sedan
#
# ...

# %%
df.rename({'New_Date':'Date'},inplace=True,axis=1)

# %%
df
# Out:
#             Time    Booking_ID Booking_Status   Customer_ID   Vehicle_Type  \
# 2       08:56:10  "CNR8494506"      Completed  "CID9202816"           Auto
# 3       17:17:25  "CNR8906825"      Completed  "CID2610914"  Premier Sedan
# 4       22:08:00  "CNR1950162"      Completed  "CID9933542"           Bike
# 5       09:44:56  "CNR4096693"      Completed  "CID4670564"           Auto
# 6       15:45:58  "CNR2002539"      Completed  "CID6800553"        Go Mini
# ...          ...           ...            ...           ...            ...
# 149995  19:34:01  "CNR6500631"      Completed  "CID4337371"        Go Mini
# 149996  15:55:09  "CNR2468611"      Completed  "CID2325623"        Go Mini
# 149997  10:55:15  "CNR6358306"      Completed  "CID9925486"       Go Sedan
# 149998  07:53:34  "CNR3030099"      Completed  "CID9415487"           Auto
# 149999  15:38:03  "CNR3447390"      Completed  "CID4108667"  Premier Sedan
#
# ...

# %%
df['Year']=df.Date.dt.year
df['Month']=df.Date.dt.month_name()
df['Day']=df.Date.dt.day_name()
df
# Out:
#             Time    Booking_ID Booking_Status   Customer_ID   Vehicle_Type  \
# 2       08:56:10  "CNR8494506"      Completed  "CID9202816"           Auto
# 3       17:17:25  "CNR8906825"      Completed  "CID2610914"  Premier Sedan
# 4       22:08:00  "CNR1950162"      Completed  "CID9933542"           Bike
# 5       09:44:56  "CNR4096693"      Completed  "CID4670564"           Auto
# 6       15:45:58  "CNR2002539"      Completed  "CID6800553"        Go Mini
# ...          ...           ...            ...           ...            ...
# 149995  19:34:01  "CNR6500631"      Completed  "CID4337371"        Go Mini
# 149996  15:55:09  "CNR2468611"      Completed  "CID2325623"        Go Mini
# 149997  10:55:15  "CNR6358306"      Completed  "CID9925486"       Go Sedan
# 149998  07:53:34  "CNR3030099"      Completed  "CID9415487"           Auto
# 149999  15:38:03  "CNR3447390"      Completed  "CID4108667"  Premier Sedan
#
# ...

# %%
df.rename({'Day':'Day_Name'},inplace=True,axis=1)

# %%
df
# Out:
#             Time    Booking_ID Booking_Status   Customer_ID   Vehicle_Type  \
# 2       08:56:10  "CNR8494506"      Completed  "CID9202816"           Auto
# 3       17:17:25  "CNR8906825"      Completed  "CID2610914"  Premier Sedan
# 4       22:08:00  "CNR1950162"      Completed  "CID9933542"           Bike
# 5       09:44:56  "CNR4096693"      Completed  "CID4670564"           Auto
# 6       15:45:58  "CNR2002539"      Completed  "CID6800553"        Go Mini
# ...          ...           ...            ...           ...            ...
# 149995  19:34:01  "CNR6500631"      Completed  "CID4337371"        Go Mini
# 149996  15:55:09  "CNR2468611"      Completed  "CID2325623"        Go Mini
# 149997  10:55:15  "CNR6358306"      Completed  "CID9925486"       Go Sedan
# 149998  07:53:34  "CNR3030099"      Completed  "CID9415487"           Auto
# 149999  15:38:03  "CNR3447390"      Completed  "CID4108667"  Premier Sedan
#
# ...

# %%
df.Vehicle_Type.unique()
# Out:
# array(['Auto', 'Premier Sedan', 'Bike', 'Go Mini', 'Go Sedan', 'Uber XL',
#        'eBike'], dtype=object)

# %%
df.rename({'Avg VTAT':'Avg_VTAT','Avg CTAT':'Avg_CTAT','Booking Value':'Booking_Value','Ride Distance':'Ride_Distance','Customer Rating':'Customer_Rating'},inplace=True,axis=1)
df
# Out:
#             Time    Booking_ID Booking_Status   Customer_ID   Vehicle_Type  \
# 2       08:56:10  "CNR8494506"      Completed  "CID9202816"           Auto
# 3       17:17:25  "CNR8906825"      Completed  "CID2610914"  Premier Sedan
# 4       22:08:00  "CNR1950162"      Completed  "CID9933542"           Bike
# 5       09:44:56  "CNR4096693"      Completed  "CID4670564"           Auto
# 6       15:45:58  "CNR2002539"      Completed  "CID6800553"        Go Mini
# ...          ...           ...            ...           ...            ...
# 149995  19:34:01  "CNR6500631"      Completed  "CID4337371"        Go Mini
# 149996  15:55:09  "CNR2468611"      Completed  "CID2325623"        Go Mini
# 149997  10:55:15  "CNR6358306"      Completed  "CID9925486"       Go Sedan
# 149998  07:53:34  "CNR3030099"      Completed  "CID9415487"           Auto
# 149999  15:38:03  "CNR3447390"      Completed  "CID4108667"  Premier Sedan
#
# ...

# %%
df.rename({'Driver Ratings':'Driver_Ratings'},inplace=True,axis=1)

# %%
df
# Out:
#             Time    Booking_ID Booking_Status   Customer_ID   Vehicle_Type  \
# 2       08:56:10  "CNR8494506"      Completed  "CID9202816"           Auto
# 3       17:17:25  "CNR8906825"      Completed  "CID2610914"  Premier Sedan
# 4       22:08:00  "CNR1950162"      Completed  "CID9933542"           Bike
# 5       09:44:56  "CNR4096693"      Completed  "CID4670564"           Auto
# 6       15:45:58  "CNR2002539"      Completed  "CID6800553"        Go Mini
# ...          ...           ...            ...           ...            ...
# 149995  19:34:01  "CNR6500631"      Completed  "CID4337371"        Go Mini
# 149996  15:55:09  "CNR2468611"      Completed  "CID2325623"        Go Mini
# 149997  10:55:15  "CNR6358306"      Completed  "CID9925486"       Go Sedan
# 149998  07:53:34  "CNR3030099"      Completed  "CID9415487"           Auto
# 149999  15:38:03  "CNR3447390"      Completed  "CID4108667"  Premier Sedan
#
# ...

# %%
df.Booking_Value.sum()
# Out:
# np.float64(47260574.0)

# %%
df.Avg_VTAT.sum()
# Out:
# np.float64(791604.7000000001)

# %%
df.Avg_CTAT.sum()
# Out:
# np.float64(2793233.8)

# %%
df.replace({'Booking_ID':{'[^0-9A-Za-z]':''},'Customer_ID':{'[^0-9A-Za-z]':''}},regex=True,inplace=True)

# %%
df
# Out:
#             Time  Booking_ID Booking_Status Customer_ID   Vehicle_Type  \
# 2       08:56:10  CNR8494506      Completed  CID9202816           Auto
# 3       17:17:25  CNR8906825      Completed  CID2610914  Premier Sedan
# 4       22:08:00  CNR1950162      Completed  CID9933542           Bike
# 5       09:44:56  CNR4096693      Completed  CID4670564           Auto
# 6       15:45:58  CNR2002539      Completed  CID6800553        Go Mini
# ...          ...         ...            ...         ...            ...
# 149995  19:34:01  CNR6500631      Completed  CID4337371        Go Mini
# 149996  15:55:09  CNR2468611      Completed  CID2325623        Go Mini
# 149997  10:55:15  CNR6358306      Completed  CID9925486       Go Sedan
# 149998  07:53:34  CNR3030099      Completed  CID9415487           Auto
# 149999  15:38:03  CNR3447390      Completed  CID4108667  Premier Sedan
#
#                Pickup_Location      Drop_Location  Avg_VTAT  Avg_CTAT  \
# ...

# %%
df.index=range(0,93000)
df
# Out:
#            Time  Booking_ID Booking_Status Customer_ID   Vehicle_Type  \
# 0      08:56:10  CNR8494506      Completed  CID9202816           Auto
# 1      17:17:25  CNR8906825      Completed  CID2610914  Premier Sedan
# 2      22:08:00  CNR1950162      Completed  CID9933542           Bike
# 3      09:44:56  CNR4096693      Completed  CID4670564           Auto
# 4      15:45:58  CNR2002539      Completed  CID6800553        Go Mini
# ...         ...         ...            ...         ...            ...
# 92995  19:34:01  CNR6500631      Completed  CID4337371        Go Mini
# 92996  15:55:09  CNR2468611      Completed  CID2325623        Go Mini
# 92997  10:55:15  CNR6358306      Completed  CID9925486       Go Sedan
# 92998  07:53:34  CNR3030099      Completed  CID9415487           Auto
# 92999  15:38:03  CNR3447390      Completed  CID4108667  Premier Sedan
#
#               Pickup_Location      Drop_Location  Avg_VTAT  Avg_CTAT  \
# ...

# %% [raw]
# df.to_csv('uber_auto_cleaned.csv',index=False)

# %%
df=pd.read_csv('c:uber_auto_cleaned.csv')
df
# Out:
#            Time  Booking_ID Booking_Status Customer_ID   Vehicle_Type  \
# 0      08:56:10  CNR8494506      Completed  CID9202816           Auto
# 1      17:17:25  CNR8906825      Completed  CID2610914  Premier Sedan
# 2      22:08:00  CNR1950162      Completed  CID9933542           Bike
# 3      09:44:56  CNR4096693      Completed  CID4670564           Auto
# 4      15:45:58  CNR2002539      Completed  CID6800553        Go Mini
# ...         ...         ...            ...         ...            ...
# 92995  19:34:01  CNR6500631      Completed  CID4337371        Go Mini
# 92996  15:55:09  CNR2468611      Completed  CID2325623        Go Mini
# 92997  10:55:15  CNR6358306      Completed  CID9925486       Go Sedan
# 92998  07:53:34  CNR3030099      Completed  CID9415487           Auto
# 92999  15:38:03  CNR3447390      Completed  CID4108667  Premier Sedan
#
#               Pickup_Location      Drop_Location  Avg_VTAT  Avg_CTAT  \
# ...

# %%
df.Booking_Value.sum()
# Out:
# np.float64(47260574.0)

# %%
df.Vehicle_Type.value_counts()
# Out:
# Vehicle_Type
# Auto             23155
# Go Mini          18549
# Go Sedan         16676
# Bike             14034
# Premier Sedan    11252
# eBike             6551
# Uber XL           2783
# Name: count, dtype: int64

# %%
plt.pie([23155,18549,16676,14034,11252,6551,2783],labels=['Auto','Go Mini','Go Sedan','Bike','Premier Sedan','eBike','Uber XL'],autopct='%.2f%%')
plt.title('Vehicles',size=20,color='b')
plt.show()

# %%
df.Month.unique()
# Out:
# array(['August', 'October', 'September', 'February', 'June', 'March',
#        'July', 'December', 'November', 'May', 'January', 'April'],
#       dtype=object)

# %%
df.Payment_Method.value_counts()
# Out:
# Payment_Method
# UPI            41834
# Cash           23114
# Uber Wallet    11206
# Credit Card     9320
# Debit Card      7526
# Name: count, dtype: int64

# %%
plt.pie([41834,23114,11206,9320,7526],labels=['UPI','Cash','Uber Wallet','Credit Card','Debit Card'],autopct='%.2f%%')
plt.title('Payment Process',size=20,color='b')
plt.show()

# %%
df.pivot_table(index=['Day_Name'],columns='Payment_Method',values='Booking_Status',aggfunc='count',margins=True)
# Out:
# Payment_Method   Cash  Credit Card  Debit Card    UPI  Uber Wallet    All
# Day_Name
# Friday           3268         1333        1052   6036         1564  13253
# Monday           3268         1343        1132   5926         1649  13318
# Saturday         3378         1370        1036   6053         1605  13442
# Sunday           3317         1331        1146   5912         1608  13314
# Thursday         3268         1331        1035   5986         1586  13206
# Tuesday          3283         1364        1051   5875         1598  13171
# Wednesday        3332         1248        1074   6046         1596  13296
# All             23114         9320        7526  41834        11206  93000

# %%
sb.countplot(y=df.Month,hue=df.Payment_Method,palette="husl")
plt.show()

# %% [markdown]
# I use Palette for color only

# %%
df.Day_Name.value_counts()
# Out:
# Day_Name
# Saturday     13442
# Monday       13318
# Sunday       13314
# Wednesday    13296
# Friday       13253
# Thursday     13206
# Tuesday      13171
# Name: count, dtype: int64

# %%
sb.countplot(y=df.Day_Name)
plt.show()
